# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from Fred2 import page_break, section

# %% [markdown]
# # My Data Report

# %%
section(['First Graph'])

d = np.random.uniform(0.0, 1.0, (2, 200))
c = np.random.randint(0, 5, 200)

sns.scatterplot(
    x = d[0],
    y = d[1],
    hue = c,
    legend = False
)

plt.show()
plt.close()
# Out:
# &nbsp;
# <style> .pagebreak { page-break-before: always; } </style><div class="pagebreak"></div>
# ## First Graph
# <hr/>

# %%
section(['Second Graph'])

d = np.random.uniform(0.0, 1.0, (2, 200))
c = np.random.randint(0, 5, 200)

sns.scatterplot(
    x = d[0],
    y = d[1],
    hue = c,
    legend = False
)

plt.show()
plt.close()
# Out:
# &nbsp;
# <style> .pagebreak { page-break-before: always; } </style><div class="pagebreak"></div>
# ## Second Graph
# <hr/>

# %%
section(
    ['Third Graph'],
    ['hey', 'there'],
)
# Out:
# &nbsp;
# <style> .pagebreak { page-break-before: always; } </style><div class="pagebreak"></div>
# ## Third Graph
# #### hey
# #### there
# <hr/>

# %% [markdown]
# This is the third graph.

# %%
d = np.random.uniform(0.0, 1.0, (2, 200))
sns.kdeplot(
    x = d[0],
    y = d[1],
)

plt.show()
plt.close()

section([], ['Here'], False)

d = np.random.uniform(0.0, 1.0, (2, 200))
sns.kdeplot(
    x = d[0],
    y = d[1],
)

plt.show()
plt.close()
# Out:
# #### Here
# <hr/>
